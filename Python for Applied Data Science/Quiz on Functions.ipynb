# %% [markdown]
# <h2>Quiz on Functions</h2>

# %% [markdown]
# Come up with a function that divides the first input by the second input:

# %%
def division(a, b):
  if b == 0:
    return("Error: Division by zero is not allowed.")
  c = a / b
  return c

# %%
division(10, 2)
# Out:
# 5.0

# %% [markdown]
# Use the function con for the following question.
# def con(a, b):
#     return(a + b)
#
# + Can the con function we defined before be used to add two integers or strings?
# + Can the con function we defined before be used to concatenate lists or tuples?

# %%
#This fuction works perfectly
def con(a, b):
    return(a + b)
c = con(10, 20)
d = con("Hello ", "World")
List1 = [1, 2, 3]
List2 = [4, 5, 6]
e = con(List1, List2)
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
f = con(tuple1, tuple2)
print(f"{c}\n{d}\n{e}\n{f}")
# Out:
# 30
# Hello World
# [1, 2, 3, 4, 5, 6]
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# Write a function code to find total count of word little in the given string: "Mary had a little lamb Little lamb, little lamb Mary had a little lamb.Its fleece was white as snow And everywhere that Mary went Mary went, Mary went Everywhere that Mary went The lamb was sure to go"**

# %%
my_string = "Mary had a little lamb Little lamb, little lamb Mary had a little lamb.Its fleece was white as snow And everywhere that Mary went Mary went, Mary went Everywhere that Mary went The lamb was sure to go"
my_list = my_string.lower().split()

def search_word(word):
    
    return(my_list.count(word))

# %%
search_word("little")
# Out:
# 4
