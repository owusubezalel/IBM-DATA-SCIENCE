# %% [markdown]
# # Quiz on object and classes

# %% [markdown]
# ## Car dealership's inventory management system

# %% [markdown]
# You are working on a Python program to simulate a car dealership's inventory management system. The system aims to model cars and their attributes accurately.

# %% [markdown]
# ### **Task-1. You are tasked with creating a Python program to represent vehicles using a class. Each car should have attributes for maximum speed and mileage.**

# %%
class vehicle:
    def __init__ (self, maximum_speed, mileage):
        self.maximum_speed = maximum_speed
        self.mileage = mileage

# %% [markdown]
# ### **Task-2. Update the class with the default color for all vehicles," white".**

# %%
class vehicle:
    def __init__ (self, maximum_speed, mileage, color = 'white'):
        self.maximum_speed = maximum_speed
        self.mileage = mileage
        self.color = color

# %% [markdown]
# ### **Task-3. Additionally, you need to create methods in the Vehicle class to assign seating capacity to a vehicle.**

# %%
class vehicle:
    def __init__ (self, maximum_speed, mileage, color = 'white'):
        self.maximum_speed = maximum_speed
        self.mileage = mileage
        self.color = color
    def seating_capacity(self,capacity):
        return capacity

# %% [markdown]
# ### **Task-4. Create a method to display all the properties of an object of the class.**

# %%
class vehicle:
    def __init__ (self, maximum_speed, mileage, color = 'white'):
        self.maximum_speed = maximum_speed
        self.mileage = mileage
        self.color = color
    def seating_capacity(self,capacity = 0):
        pass
    def properties_display(self):
        return (f'Maximum Speed: {self.maximum_speed} km/hr, Mileage: {self.mileage} km/l, Color: {self.color}, Seating Capacity: {self.seating_capacity()}')

# %% [markdown]
# ### **Task-5. Additionally, you need to create two objects of the Vehicle class object that should have a max speed of 200kmph and mileage of 20kmpl with five seating capacities, and another car object should have a max speed of 180kmph and mileage of 25kmpl with four seating capacities.**

# %%
Object1 = vehicle(200, 20)
Object2 = vehicle(180, 25)
Object1.seating_capacity(5)
Object1.properties_display()
Object2.seating_capacity(4)
Object2.properties_display()
print(f'The properties of Object1 are: {Object1.properties_display()} \nThe properties of Object2 are: {Object2.properties_display()}')
# Out:
# The properties of Object1 are: Maximum Speed: 200 km/hr, Mileage: 20 km/l, Color: white, Seating Capacity: None
# The properties of Object2 are: Maximum Speed: 180 km/hr, Mileage: 25 km/l, Color: white, Seating Capacity: None
